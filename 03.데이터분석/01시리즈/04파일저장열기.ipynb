# %%
import pandas as pd

# %%
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']
}

# %%
df3=pd.DataFrame(data,index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df3
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  북산고  197   90   85  100  95  85      Python
# 2번  정대만  북산고  184   40   35   50  55  25        Java
# 3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번  서태웅  북산고  187   40   60   70  75  80
# 5번  강백호  북산고  188   15   20   10  35  10
# 6번  변덕규  능남고  202   80  100   95  85  80           C
# 7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df2=df3.sort_values(['학교','키'],ascending=[True,False])
df2
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 6번  변덕규  능남고  202   80  100   95  85  80           C
# 8번  윤대협  능남고  190  100   85   90  95  95          C#
# 7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 1번  채치수  북산고  197   90   85  100  95  85      Python
# 5번  강백호  북산고  188   15   20   10  35  10
# 4번  서태웅  북산고  187   40   60   70  75  80
# 2번  정대만  북산고  184   40   35   50  55  25        Java
# 3번  송태섭  북산고  168   80   75   70  80  75  Javascript

# %%
# 타 program으로 저장(ex.df2로 저장) csv로 저장
df2.to_csv('data/학교키순정렬.csv',encoding='utf-8-sig')

# %%
df2.to_csv('data/학교키순정렬2.csv',encoding='utf-8-sig', index=False) # 인덱스를 포함 X

# %%
df2.to_csv('data/학교키순정렬.txt',sep='\t') #값과 값 사이를 tab('\t')으로 구분

# %%
df2.to_csv('data/학교키정렬.xlsx',encoding='utf-8-sig')

# %%
#데이터 파일 불러오기
df4=pd.read_csv('data/학교키순정렬.csv', skiprows=1)
df4
# Out:
#    6번  변덕규  능남고  202   80  100   95  85  80.1           C
# 0  8번  윤대협  능남고  190  100   85   90  95    95          C#
# 1  7번  황태산  능남고  188   55   65   45  40    35      PYTHON
# 2  1번  채치수  북산고  197   90   85  100  95    85      Python
# 3  5번  강백호  북산고  188   15   20   10  35    10         NaN
# 4  4번  서태웅  북산고  187   40   60   70  75    80         NaN
# 5  2번  정대만  북산고  184   40   35   50  55    25        Java
# 6  3번  송태섭  북산고  168   80   75   70  80    75  Javascript

# %%
df4=pd.read_csv('data/학교키순정렬.csv', skiprows=1) #1행을 스킵하기
df4
# Out:
#    6번  변덕규  능남고  202   80  100   95  85  80.1           C
# 0  8번  윤대협  능남고  190  100   85   90  95    95          C#
# 1  7번  황태산  능남고  188   55   65   45  40    35      PYTHON
# 2  1번  채치수  북산고  197   90   85  100  95    85      Python
# 3  5번  강백호  북산고  188   15   20   10  35    10         NaN
# 4  4번  서태웅  북산고  187   40   60   70  75    80         NaN
# 5  2번  정대만  북산고  184   40   35   50  55    25        Java
# 6  3번  송태섭  북산고  168   80   75   70  80    75  Javascript

# %%
df5=pd.read_csv('data/학교키순정렬.csv', skiprows=[1]) #1행, 3행, 5행을 스킵함(황태산, 강백호,)
df5
# Out:
#   Unnamed: 0   이름   학교    키   국어  영어   수학  과학  사회        SW특기
# 0         8번  윤대협  능남고  190  100  85   90  95  95          C#
# 1         7번  황태산  능남고  188   55  65   45  40  35      PYTHON
# 2         1번  채치수  북산고  197   90  85  100  95  85      Python
# 3         5번  강백호  북산고  188   15  20   10  35  10         NaN
# 4         4번  서태웅  북산고  187   40  60   70  75  80         NaN
# 5         2번  정대만  북산고  184   40  35   50  55  25        Java
# 6         3번  송태섭  북산고  168   80  75   70  80  75  Javascript

# %%
df5=pd.read_csv('data/학교키순정렬.csv', nrows=4) #앞 4개의 행만 필요함
df5
# Out:
#   Unnamed: 0   이름   학교    키   국어   영어   수학  과학  사회    SW특기
# 0         6번  변덕규  능남고  202   80  100   95  85  80       C
# 1         8번  윤대협  능남고  190  100   85   90  95  95      C#
# 2         7번  황태산  능남고  188   55   65   45  40  35  PYTHON
# 3         1번  채치수  북산고  197   90   85  100  95  85  Python

# %%
df3=pd.read_csv('data/학교키순정렬.txt',sep='\t') #탭 기준으로 나누고, 인덱스 번호를 '지원번호'로 지정함
df3.set_index('지원번호', inplace=True)
df3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[173], line 2
#       1 df3=pd.read_csv('data/학교키순정렬.txt',sep='\t') #탭 기준으로 나누고, 인덱스 번호를 '지원번호'로 지정함
# ----> 2 df3.set_index('지원번호', inplace=True)
#       3 df3
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:6129, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6126                 missing.append(col)
#    6128 if missing:
# -> 6129     raise KeyError(f"None of {missing} are in the columns")
#    6131 if inplace:
#    6132     frame = self
#
# KeyError: "None of ['지원번호'] are in the columns"

# %%
df6=pd.read_excel('data/학교키정렬.xlsx', index_col='지원번호')
df6
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 df6=pd.read_excel('data/학교키순정렬.xlsx', index_col='지원번호')
#       2 df6
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...

# %%
df3.index.name='지원번호'
df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df3.index.name='지원번호'
#       2 df3
#
# NameError: name 'df3' is not defined
